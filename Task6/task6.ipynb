# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("stack_network_links.csv")

# %%
df.head()
# Out:
#              source target      value
# 0             azure   .net  20.933192
# 1        sql-server   .net  32.322524
# 2           asp.net   .net  48.407030
# 3  entity-framework   .net  24.370903
# 4               wpf   .net  32.350925

# %%
df.tail()
# Out:
#              source     target      value
# 24       typescript    angular  31.036482
# 25       typescript   angular2  38.879982
# 26        angularjs   angular2  26.032697
# 27  ionic-framework  angularjs  29.840446
# 28          reactjs  angularjs  31.620202

# %%
G = nx.Graph()
for i, row in df.iterrows():
    G.add_edge(row['source'], row['target'], weight=row['value'])

# %%
pos = nx.spring_layout(G, k=2.0, iterations=35)

# %%
plt.figure(figsize=(10,8))

nx.draw_networkx_nodes(G, pos, node_size=1500)
nx.draw_networkx_edges(G, pos, width=1)
nx.draw_networkx_labels(G, pos, font_size=9)

plt.title("Force Based Layout Graph of Technology Stack")
plt.axis("on")

plt.show()
